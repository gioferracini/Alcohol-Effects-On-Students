# %% [markdown]
# ## **Attributes for both Maths.csv (Math course) datasets:**
#
# ![image.png](data:image/png;base64,...)
#
# ## **These grades are related with the course subject, Math or Portuguese:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Importing the Packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Exploring the dataset**

# %%
math = pd.read_csv("/kaggle/input/alcohol-effects-on-study/Maths.csv", sep = ',')
math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
math.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
math.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# # **Visualization of data**

# %%
graph = sns.countplot(math['sex'])

# %%
def catplot(x, title):
  ax = sns.catplot(x = x, kind = 'count', hue = 'sex', data = math).set(title = title)
  ax.figure.set_size_inches(8, 6)

catplot('school', 'Total of students at each school by gender')

# %%
catplot('age', 'Total of age by gender')

# %%
catplot('famsize', 'Total family size by Gender')

# %%
catplot('address', 'Total of people who lives in rural or countryside')

# %%
catplot('Pstatus', 'Total of students who lives alone or together with the parents')

# %%
catplot('Medu', 'Total of mothers education')

# %%
catplot('Fedu', 'Total of fathers education')

# %%
catplot('Mjob', 'Total of mothers job')

# %%
catplot('Fjob', 'Total of fathers job')

# %%
catplot('reason', 'Total of reason to choose the school')

# %%
catplot('guardian', 'Total of students guardian')

# %%
catplot('traveltime', 'Total of distance between school and home')

# %%
catplot('studytime', 'Total of weekly study time')

# %%
catplot('failures', 'Total of past class failures')

# %%
catplot('schoolsup', 'Total of extra education support')

# %%
catplot('famsup', 'Total of family education support')

# %%
catplot('paid', 'Total of extra paid classes')

# %%
catplot('activities', 'Total of extra-curricular activities')

# %%
catplot('nursery', 'Total of who attended nusery school')

# %%
catplot('higher', 'Total of who wants to take higher education')

# %%
catplot('internet', 'Total of who has access of internet at home')

# %%
catplot('romantic', 'Total of who has a romantic relationship')

# %%
catplot('famrel', 'Total of quality of family relationships')

# %%
catplot('freetime', 'Total of free time after school')

# %%
catplot('goout', 'Total of going out with friends')

# %%
catplot('Dalc', 'Total of workday alcohol consumption')

# %%
catplot('Walc', 'Total of weekend alcohol consumption')

# %%
catplot('health', 'Total of current health status')

# %%
catplot('absences', 'Total of absences')

# %%
graph = sns.histplot(x = 'G1', data = math, bins = 10)
graph.set_title('Distribution of 1st period grade (general)', fontsize = 14)
graph.figure.set_size_inches(8, 6)

# %%
graph = sns.histplot(x = 'G2', data = math, bins = 10)
graph.set_title('Distribution of 2nd period grade (general)', fontsize = 14)
graph.figure.set_size_inches(8, 6)

# %%
graph = sns.histplot(x = 'G3', data = math, bins = 10)
graph.set_title('Distribution of 3rd period grade (general)', fontsize = 14)
graph.figure.set_size_inches(8, 6)

# %%
graph = sns.histplot(x = 'G1', data = math.query('sex == "M"'), color = 'green', bins = 10)
graph = sns.histplot(x = 'G1', data = math.query('sex == "F"'), color = 'pink', bins = 10)
graph.set_title('Distribution of 1st period grade (by gender)', fontsize = 14)
graph.figure.set_size_inches(8, 6)

# %%
graph = sns.histplot(x = 'G2', data = math.query('sex == "M"'), color = 'green', bins = 10)
graph = sns.histplot(x = 'G2', data = math.query('sex == "F"'), color = 'pink', bins = 10)
graph.set_title('Distribution of 2nd period grade (by gender)', fontsize = 14)
graph.figure.set_size_inches(8, 6)

# %%
graph = sns.histplot(x = 'G3', data = math.query('sex == "M"'), color = 'green', bins = 10)
graph = sns.histplot(x = 'G3', data = math.query('sex == "F"'), color = 'pink', bins = 10)
graph.set_title('Distribution of 3rd period grade (by gender)', fontsize = 14)
graph.figure.set_size_inches(8, 6)

# %%
print("G1's females grade mean %.2f" % math.query('sex == "F"')['G1'].mean())
print("G2's females grade mean %.2f" % math.query('sex == "F"')['G2'].mean())
print("G3's females grade mean %.2f" % math.query('sex == "F"')['G3'].mean())
print(" ")
print("G1's males grade mean %.2f" % math.query('sex == "M"')['G1'].mean())
print("G2's males grade mean %.2f" % math.query('sex == "M"')['G2'].mean())
print("G3's males grade mean %.2f" % math.query('sex == "M"')['G3'].mean())
print(" ")
print("G1's females grade median %.2f" % math.query('sex == "F"')['G1'].median())
print("G2's females grade median %.2f" % math.query('sex == "F"')['G2'].median())
print("G3's females grade median %.2f" % math.query('sex == "F"')['G3'].median())
print(" ")
print("G1's males grade median %.2f" % math.query('sex == "M"')['G1'].median())
print("G2's males grade median %.2f" % math.query('sex == "M"')['G2'].median())
print("G3's males grade median %.2f" % math.query('sex == "M"')['G3'].median())
# Out:
# G1's females grade mean 10.62
# G2's females grade mean 10.39
# G3's females grade mean 9.97
#
# G1's males grade mean 11.23
# G2's males grade mean 11.07
# G3's males grade mean 10.91
#
# G1's females grade median 10.00
# G2's females grade median 10.00
# G3's females grade median 10.00
#
# G1's males grade median 11.00
# G2's males grade median 11.00
# G3's males grade median 11.00

# %% [markdown]
# ## **What the data show for us?**
#
# As we can looking, the great part of the students are females that presents the best grades in study, with more time weekly to dedicate on the studies, as well as some of them have extra paid classes to help in the class.
#
# Meanwhile, it's possible to worry about the male's data. Because the number of the alcohol consumption increase is meanly higher than females, with less time of study, more to drink and badly health situation.
#
# However, the ironic is the male's grade presents bigger than female in general. Although the both show for us the grades like a normal distribution, when we join the sexies to compare how is it, the male's grade is nexter the biggest grade.

# %% [markdown]
# ## **New categories to the columns**

# %%
#Convert the categoricals objects to int

math['school'].replace(to_replace=['GP','MS'], value = [0, 1], inplace = True)
math['sex'].replace(to_replace=['M','F'], value = [0, 1], inplace = True)
math['address'].replace(to_replace=['U','R'], value = [0, 1], inplace = True)
math['famsize'].replace(to_replace=['LE3','GT3'], value = [0, 1], inplace = True)
math['Pstatus'].replace(to_replace=['T','A'], value = [0, 1], inplace = True)
math['Mjob'].replace(to_replace=['at_home','teacher', 'health', 'services', 'other'], value = [0, 1, 2, 3, 4], inplace = True)
math['Fjob'].replace(to_replace=['at_home','teacher', 'health', 'services', 'other'], value = [0, 1, 2, 3, 4], inplace = True)
math['reason'].replace(to_replace=['home','reputation', 'course', 'other'], value = [0, 1, 2, 3], inplace = True)
math['guardian'].replace(to_replace=['mother','father','other'], value = [0, 1, 2], inplace = True)
math['schoolsup'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)
math['famsup'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)
math['paid'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)
math['activities'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)
math['nursery'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)
math['higher'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)
math['internet'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)
math['romantic'].replace(to_replace=['no','yes'], value = [0, 1], inplace = True)

# %% [markdown]
# **School:** 0 - Gabriel Pereira / 1 - Mousinho da Silveira
#
# **Sex:** 0 - Male / 1 - Female
#
# **Address:** 0 - Urban / 1 - Rural
#
# **Famsize:** 0 - Less than 3 people / 1 - Greater than 3 people
#
# **Pstatus:** 0 - Living together / 1 - Apart
#
# **Mjob:** 0 - At home / 1 - Teacher / 2 - Health / 3 - Services / 4 - Other
#
# **Fjob:** 0 - At home / 1 - Teacher / 2 - Health / 3 - Services / 4 - Other
#
# **Reason:** 0 - Home / 1 - Reputation / 2 - Course / 3 - Other
#
# **Guardian:** 0 - Mother / 1 - Father / 2 - Other
#
# **Schoolsup:** 0 - No / 1 - Yes
#
# **Famsup:** 0 - No / 1 - Yes
#
# **Paid:** 0 - No / 1 - Yes
#
# **Activities:** 0 - No / 1 - Yes
#
# **Nursery:** 0 - No / 1 - Yes
#
# **Higher:** 0 - No / 1 - Yes
#
# **Internet:** 0 - No / 1 - Yes
#
# **Romantic:** 0 - No / 1 - Yes

# %%
corr = math.corr()
graph = sns.heatmap(corr, annot = True, fmt = '.2f')
graph.figure.set_size_inches(24, 16)
graph.set_title('Correlation Matriz', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Correlation Matriz')

# %%
#Create a copy database

math_2 = math.copy()
math_2
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    1   18        0        1        1     4     4     0     1  ...
# 1         0    1   17        0        1        0     1     1     0     4  ...
# 2         0    1   15        0        0        0     1     1     0     4  ...
# 3         0    1   15        0        1        0     4     2     2     3  ...
# 4         0    1   16        0        1        0     3     3     4     4  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    0   20        0        0        1     2     2     3     3  ...
# 391       1    0   17        0        0        0     3     1     3     3  ...
# 392       1    0   21        1        1        0     1     1     4     4  ...
# 393       1    0   18        1        0        0     3     2     3     4  ...
# 394       1    0   19        0        0        0     1     1     4     0  ...
#
# ...

# %% [markdown]
# # **We're going to start working the data to divide the students by clusters**

# %%
#Separating the dataset in 2

X = math_2.iloc[:, :32]
y = math_2.iloc[:, 32:33]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

k_best = SelectKBest(chi2, k = 10)
k_best.fit(X, y)

col = k_best.get_support(1)
math_3 = X[X.columns[col]]
math_3 = math_3.join(y)
math_copy = math_3.copy()
math_copy
# Out:
#      address  Mjob  failures  schoolsup  romantic  Dalc  Walc  absences  G1  \
# 0          0     0         0          1         0     1     1         6   5
# 1          0     0         0          0         0     1     1         4   5
# 2          0     0         3          1         0     2     3        10   7
# 3          0     2         0          0         1     1     1         2  15
# 4          0     4         0          0         0     1     2         4   6
# ..       ...   ...       ...        ...       ...   ...   ...       ...  ..
# 390        0     3         2          0         0     4     5        11   9
# 391        0     3         0          0         0     3     4         3  14
# 392        1     4         3          0         0     3     3         3  10
# 393        1     3         0          0         0     3     4         0  11
# 394        0     4         0          0         0     3     3         5   8
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# ...

# %% [markdown]
# After we have discovered the best features of dataset, we're going to work it separating the categorical columns, to unique each one to process how will affect between then in the correlation matriz.

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(dtype = int)
address_ohe = ohe.fit_transform(math_3[['address']]).toarray()
math_3 = math_3.drop(columns = 'address', axis = 1)
math_3 = pd.concat([math_3, pd.DataFrame(address_ohe, columns = ohe.get_feature_names_out(['address']))], axis = 1)

Mjob_ohe = ohe.fit_transform(math_3[['Mjob']]).toarray()
math_3 = math_3.drop(columns = 'Mjob', axis = 1)
math_3 = pd.concat([math_3, pd.DataFrame(Mjob_ohe, columns = ohe.get_feature_names_out(['Mjob']))], axis = 1)

failures_ohe = ohe.fit_transform(math_3[['failures']]).toarray()
math_3 = math_3.drop(columns = 'failures', axis = 1)
math_3 = pd.concat([math_3, pd.DataFrame(failures_ohe, columns = ohe.get_feature_names_out(['failures']))], axis = 1)

schoolsup_ohe = ohe.fit_transform(math_3[['schoolsup']]).toarray()
math_3 = math_3.drop(columns = 'schoolsup', axis = 1)
math_3 = pd.concat([math_3, pd.DataFrame(schoolsup_ohe, columns = ohe.get_feature_names_out(['schoolsup']))], axis = 1)

romantic_ohe = ohe.fit_transform(math_3[['romantic']]).toarray()
math_3 = math_3.drop(columns = 'romantic', axis = 1)
math_3 = pd.concat([math_3, pd.DataFrame(romantic_ohe, columns = ohe.get_feature_names_out(['romantic']))], axis = 1)

Dalc_ohe = ohe.fit_transform(math_3[['Dalc']]).toarray()
math_3 = math_3.drop(columns = 'Dalc', axis = 1)
math_3 = pd.concat([math_3, pd.DataFrame(Dalc_ohe, columns = ohe.get_feature_names_out(['Dalc']))], axis = 1)

Walc_ohe = ohe.fit_transform(math_3[['Walc']]).toarray()
math_3 = math_3.drop(columns = 'Walc', axis = 1)
math_3 = pd.concat([math_3, pd.DataFrame(Walc_ohe, columns = ohe.get_feature_names_out(['Walc']))], axis = 1)

# %% [markdown]
# # **Standardizing the data**

# %%
from sklearn.preprocessing import StandardScaler

standardizer = StandardScaler()
standardizer.fit(math_3)
math_4 = standardizer.transform(math_3)
math_4 = pd.DataFrame(data = math_4, columns = math_3.keys())

# %%
corr = math_4.corr()
graph = sns.heatmap(corr, annot = True, fmt = '.2f')
graph.figure.set_size_inches(24, 16)
graph.set_title('Correlation Matriz', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Correlation Matriz')

# %% [markdown]
# # **Identifying the distribution of clusters in a graph**

# %%
SEED = 1234
np.random.seed(1234)

from sklearn.decomposition import PCA 

pca = PCA(n_components = 2, random_state = SEED)
math_pca = pca.fit_transform(math_4)
math_pca_info = pd.DataFrame(columns = ['X', 'y'], data = math_pca)
math_pca_info
# Out:
#             X         y
# 0    0.928737 -3.976668
# 1    0.604801 -2.072278
# 2    3.299781 -0.896849
# 3   -2.512769 -0.455486
# 4   -0.152376 -0.682524
# ..        ...       ...
# 390  2.737944  1.719004
# 391 -1.257255  2.979879
# 392  3.378321  1.860493
# 393  0.862014  2.923681
# 394  0.830515  1.427492
#
# [395 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

kmeans_pca = KMeans(n_clusters = 5, verbose = True, random_state = SEED)
kmeans_pca.fit(math_pca_info)
math_pca_info['cluster_pca'] = kmeans_pca.predict(math_pca_info)
# Out:
# Initialization complete
# Iteration 0, inertia 714.0488740730548
# Iteration 1, inertia 551.7403415785388
# Iteration 2, inertia 537.1837077022689
# Iteration 3, inertia 530.7449946842974
# Iteration 4, inertia 527.180688196499
# Iteration 5, inertia 525.7441992454142
# Iteration 6, inertia 525.6031875967473
# Converged at iteration 6: strict convergence.
# Initialization complete
# Iteration 0, inertia 771.9075947901707
# Iteration 1, inertia 591.7161106432917
# Iteration 2, inertia 562.1133099706378
# Iteration 3, inertia 553.3458282474273
# Iteration 4, inertia 544.3935870908767
# Iteration 5, inertia 537.6982087087397
# Iteration 6, inertia 532.4814569269
# Iteration 7, inertia 526.4148782741372
# Iteration 8, inertia 525.6031875967473
# Converged at iteration 8: strict convergence.
# Initialization complete
# Iteration 0, inertia 827.0121523556812
# Iteration 1, inertia 615.4567152500546
# Iteration 2, inertia 585.915869726536
# Iteration 3, inertia 579.9443280772559
# ...

# %%
math_pca_info
# Out:
#             X         y  cluster_pca
# 0    0.928737 -3.976668            3
# 1    0.604801 -2.072278            3
# 2    3.299781 -0.896849            0
# 3   -2.512769 -0.455486            1
# 4   -0.152376 -0.682524            2
# ..        ...       ...          ...
# 390  2.737944  1.719004            0
# 391 -1.257255  2.979879            4
# 392  3.378321  1.860493            0
# 393  0.862014  2.923681            4
# 394  0.830515  1.427492            4
#
# [395 rows x 3 columns]

# %%
import plotly.express as px

fig = px.scatter(
    math_pca_info, x = 'X', y = 'y', color = 'cluster_pca', hover_data=['X', 'y', 'cluster_pca'] 
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
math_description = math_copy.join(math_pca_info['cluster_pca'])
math_description
# Out:
#      address  Mjob  failures  schoolsup  romantic  Dalc  Walc  absences  G1  \
# 0          0     0         0          1         0     1     1         6   5
# 1          0     0         0          0         0     1     1         4   5
# 2          0     0         3          1         0     2     3        10   7
# 3          0     2         0          0         1     1     1         2  15
# 4          0     4         0          0         0     1     2         4   6
# ..       ...   ...       ...        ...       ...   ...   ...       ...  ..
# 390        0     3         2          0         0     4     5        11   9
# 391        0     3         0          0         0     3     4         3  14
# 392        1     4         3          0         0     3     3         3  10
# 393        1     3         0          0         0     3     4         0  11
# 394        0     4         0          0         0     3     3         5   8
#
#      G2  G3  cluster_pca
# 0     6   6            3
# ...

# %% [markdown]
# # **As the dataset is small, we're going to use the median value to identify how were composed the clusters**

# %%
description = math_description.groupby('cluster_pca')['address', 'Mjob', 'failures', 'schoolsup', 'romantic', 'Dalc', 'Walc', 'absences', 'G1', 'G2', 'G3']
n_students = description.size()
description = description.median()
description['n_students'] = n_students
print(description)
# Out:
#              address  Mjob  failures  schoolsup  romantic  Dalc  Walc  \
# cluster_pca
# 0                0.0   3.0       1.0        0.0       0.0   2.0   3.0
# 1                0.0   3.0       0.0        0.0       0.0   1.0   1.0
# 2                0.0   3.0       0.0        0.0       0.0   1.0   2.0
# 3                0.0   3.0       0.0        1.0       0.0   1.0   1.0
# 4                0.0   3.0       0.0        0.0       0.0   2.0   3.0
#
#              absences    G1    G2    G3  n_students
# cluster_pca
# 0                 6.0   7.0   8.0   7.0          65
# 1                 2.0  15.0  15.0  15.0          91
# 2                 4.0  10.0  10.0  10.0         107
# 3                 2.0   8.0   8.0   8.0          56
# 4                 4.0  12.0  12.0  12.0          76

# %% [markdown]
# **Cluster 0:** The cluster with lower grades and presents the highest number of absences and alcohol consumption. Probably the worst math' students of dataset.
#
# **Cluster 1:** The cluster with lower alcohol consumption and highest math's grades. Probably the best math' students of dataset.
#
# **Cluster 2:** The cluster composed from most students. These have a low alcohol consumption, however, the grades are mean and the number of absences are a little troublesome.
#
# **Cluster 3:** The cluster with less number of students. These need support classes because their grades are low even with few alcohol consumption. Maybe there're other reasons besides of alcohol to explain the badly performance.
#
# **Cluster 4:** A curious case. Because equal the cluster 0, this presents a high alcohol consumption, but the grades are good too. Maybe the consumption are big because they are experient students and know the subject.
